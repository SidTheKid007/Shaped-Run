# %%
import geopy
from geopy.distance import geodesic
from geopy.geocoders import Nominatim
import folium
from branca.element import Figure
import ipywidgets as widgets
import osmnx as ox
import networkx as nx

# %% [markdown]
# ## Folium Experiments

# %%
coords_1=[[28.65685,77.21899],[28.63004,77.22135]]
coords_2=[[28.63382,77.22045],[28.64022,77.23153]]
coords_3=[[28.63216,77.21864],[28.64659,77.20495]]
fig5=Figure(height=550,width=750)
m5=folium.Map(location=[28.644800, 77.216721],tiles='cartodbpositron',zoom_start=14)
fig5.add_child(m5)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdfd3ee89fa714b18d13ae3dfe3a2f6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdfd3ee89fa714b18d13ae3dfe3a2f6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cdfd3ee89fa714b18d13ae3dfe3a2f6e = L.map(
#                 &quot;map_cdfd3ee89fa714b18d13ae3dfe3a2f6e&quot;,
#                 {
#                     center: [28.6448, 77.216721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3287dc303d2ec6697d1274d42140cb75 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cdfd3ee89fa714b18d13ae3dfe3a2f6e);
#
# &lt;/script&gt;" width="750" height="550"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# Creating feature groups
f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")
f3=folium.FeatureGroup("Vehicle 3")

# Adding lines to the different feature groups
line_1=folium.vector_layers.PolyLine(coords_1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(coords_2,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
line_3=folium.vector_layers.PolyLine(coords_3,popup='<b>Path of Vehicle_3</b>',tooltip='Vehicle_3',color='green',weight=10).add_to(f3)

f1.add_to(m5)
f2.add_to(m5)
f3.add_to(m5)
folium.LayerControl().add_to(m5)
m5
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdfd3ee89fa714b18d13ae3dfe3a2f6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdfd3ee89fa714b18d13ae3dfe3a2f6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cdfd3ee89fa714b18d13ae3dfe3a2f6e = L.map(
#                 &quot;map_cdfd3ee89fa714b18d13ae3dfe3a2f6e&quot;,
#                 {
#                     center: [28.6448, 77.216721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3287dc303d2ec6697d1274d42140cb75 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cdfd3ee89fa714b18d13ae3dfe3a2f6e);
#
#
#             var feature_group_b628d1027e81732c0410dfda109e7d70 = L.featureGroup(
#                 {}
#             ).addTo(map_cdfd3ee89fa714b18d13ae3dfe3a2f6e);
#
#
#             var poly_line_3dc8bf19716d0b0d653902c7576be4f6 = L.polyline(
#                 [[28.65685, 77.21899], [28.63004, 77.22135]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_b628d1027e81732c0410dfda109e7d70);
#
#
#         var popup_22e7a85c73a6456578aed3be142484d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9a42baea7024d7bf1a44cea2ccc121ad = $(`&lt;div id=&quot;html_9a42baea7024d7bf1a44cea2ccc121ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Path of Vehicle_1&lt;/b&gt;&lt;/div&gt;`)[0];
#             popup_22e7a85c73a6456578aed3be142484d7.setContent(html_9a42baea7024d7bf1a44cea2ccc121ad);
#
#
#         poly_line_3dc8bf19716d0b0d653902c7576be4f6.bindPopup(popup_22e7a85c73a6456578aed3be142484d7)
#         ;
#
#
#
#
#             poly_line_3dc8bf19716d0b0d653902c7576be4f6.bindTooltip(
#                 `&lt;div&gt;
#                      Vehicle_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var feature_group_c6a58e41b9c75b7110a13d1224ba1f38 = L.featureGroup(
#                 {}
#             ).addTo(map_cdfd3ee89fa714b18d13ae3dfe3a2f6e);
#
#
#             var poly_line_acb8f840f151dc6f83852bb5e38fecfb = L.polyline(
#                 [[28.63382, 77.22045], [28.64022, 77.23153]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_c6a58e41b9c75b7110a13d1224ba1f38);
#
#
#         var popup_8c76590f5ebe1ac5bbc96af0fcb69893 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_94e5f8a2065d05735e2852b3bffbce95 = $(`&lt;div id=&quot;html_94e5f8a2065d05735e2852b3bffbce95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Path of Vehicle_2&lt;/b&gt;&lt;/div&gt;`)[0];
#             popup_8c76590f5ebe1ac5bbc96af0fcb69893.setContent(html_94e5f8a2065d05735e2852b3bffbce95);
#
#
#         poly_line_acb8f840f151dc6f83852bb5e38fecfb.bindPopup(popup_8c76590f5ebe1ac5bbc96af0fcb69893)
#         ;
#
#
#
#
#             poly_line_acb8f840f151dc6f83852bb5e38fecfb.bindTooltip(
#                 `&lt;div&gt;
#                      Vehicle_2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var feature_group_ce021bed1185ad8ca66a2920888feb15 = L.featureGroup(
#                 {}
#             ).addTo(map_cdfd3ee89fa714b18d13ae3dfe3a2f6e);
#
#
#             var poly_line_12a30a8485ca0b4d598e864a38d1e242 = L.polyline(
#                 [[28.63216, 77.21864], [28.64659, 77.20495]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_gro

# %% [markdown]
# ## Calculating shapes

# %%
StartLat = 39.164260
StartLong = -118.050480
TotalDist = 5

# %% [markdown]
# ### Square

# %%
SideDist = TotalDist/4
origin = geopy.Point(StartLat, StartLong)
Stop1 = geodesic(kilometers=SideDist).destination(origin, 90)
Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
Stop2 = geodesic(kilometers=SideDist).destination(Stop1, 180)
Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
Stop3 = geodesic(kilometers=SideDist).destination(origin, 180)
Stop3Lat, Stop3Long = Stop3.latitude, Stop3.longitude

# %%
coords_1=[[StartLat,StartLong],[Stop1Lat,Stop1Long],[Stop2Lat,Stop2Long],[Stop3Lat,Stop3Long],[StartLat,StartLong]]
fig5=Figure(height=550,width=750)
m5=folium.Map(location=[StartLat, StartLong],tiles='cartodbpositron',zoom_start=14)

# %%
f1=folium.FeatureGroup("Vehicle 1")
line_1=folium.vector_layers.PolyLine(coords_1,tooltip='First Line',color='blue',weight=10).add_to(f1)
folium.Marker(location=[StartLat,StartLong],icon=folium.Icon(color='red',icon='none')).add_to(m5)
f1.add_to(m5)
folium.LayerControl().add_to(m5)
m5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1032f601c6cef3e1b54313ceab6e6ea8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1032f601c6cef3e1b54313ceab6e6ea8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1032f601c6cef3e1b54313ceab6e6ea8 = L.map(
#                 &quot;map_1032f601c6cef3e1b54313ceab6e6ea8&quot;,
#                 {
#                     center: [39.16426, -118.05048],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf60e8560e0601bc4ac6893ba0a5e665 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1032f601c6cef3e1b54313ceab6e6ea8);
#
#
#             var marker_f3271c5ced6769ab76d94a7b3f7bb6a0 = L.marker(
#                 [39.16426, -118.05048],
#                 {}
#             ).addTo(map_1032f601c6cef3e1b54313ceab6e6ea8);
#
#
#             var icon_c45c82c38ae310457a64fb45e600c126 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3271c5ced6769ab76d94a7b3f7bb6a0.setIcon(icon_c45c82c38ae310457a64fb45e600c126);
#
#
#             var feature_group_88248a7aa43f1ef25f212285f097b1e8 = L.featureGroup(
#                 {}
#             ).addTo(map_1032f601c6cef3e1b54313ceab6e6ea8);
#
#
#             var poly_line_9a539a7839343919e8451d512a040208 = L.polyline(
#                 [[39.16426, -118.05048], [39.16425910250252, -118.0360167187888], [39.15299971880596, -118.0360167187888], [39.15300061630519, -118.05048], [39.16426, -118.05048]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_88248a7aa43f1ef25f212285f097b1e8);
#
#
#             poly_line_9a539a7839343919e8451d512a040208.bindTooltip(
#                 `&lt;div&gt;
#                      First Line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var layer_control_fed2ae830599fd635ff4a05b1b73e7ab = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_bf60e8560e0601bc4ac6893ba0a5e665,
#                 },
#                 overlays :  {
#                     &quot;Vehicle 1&quot; : feature_group_88248a7aa43f1ef25f212285f097b1e8,
#                 },
#             };
#             L.control.layers(
#                 layer_control_fed2ae830599fd635ff4a05b1b73e7ab.base_layers,
#                 layer_control_fed2ae830599fd635ff4a05b1b73e7ab.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_1032f601c6cef3e1b54313ceab6e6ea8);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Triangle

# %%
SideDist = TotalDist/3
origin = geopy.Point(StartLat, StartLong)
Stop1 = geodesic(kilometers=SideDist).destination(origin, 150)
Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
Stop2 = geodesic(kilometers=SideDist).destination(origin, 210)
Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude

# %%
coords_1=[[StartLat,StartLong],[Stop1Lat,Stop1Long],[Stop2Lat,Stop2Long],[StartLat,StartLong]]
fig5=Figure(height=550,width=750)
m5=folium.Map(location=[StartLat, StartLong],tiles='cartodbpositron',zoom_start=14)

# %%
f1=folium.FeatureGroup("Vehicle 1")
line_1=folium.vector_layers.PolyLine(coords_1,tooltip='First Line',color='blue',weight=10).add_to(f1)
folium.Marker(location=[StartLat,StartLong],icon=folium.Icon(color='red',icon='none')).add_to(m5)
f1.add_to(m5)
folium.LayerControl().add_to(m5)
m5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb16d9d6bba483f4340af8e34be20945 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb16d9d6bba483f4340af8e34be20945&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_bb16d9d6bba483f4340af8e34be20945 = L.map(
#                 &quot;map_bb16d9d6bba483f4340af8e34be20945&quot;,
#                 {
#                     center: [39.16426, -118.05048],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e15fb65db94a44c16c840a788a16de6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb16d9d6bba483f4340af8e34be20945);
#
#
#             var marker_0c2d165d17fe6e8eb944446254aab7bb = L.marker(
#                 [39.16426, -118.05048],
#                 {}
#             ).addTo(map_bb16d9d6bba483f4340af8e34be20945);
#
#
#             var icon_eff9681a965a34644c0a63bdba754013 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c2d165d17fe6e8eb944446254aab7bb.setIcon(icon_eff9681a965a34644c0a63bdba754013);
#
#
#             var feature_group_b9943d0b560c6139a299459255e8066c = L.featureGroup(
#                 {}
#             ).addTo(map_bb16d9d6bba483f4340af8e34be20945);
#
#
#             var poly_line_c2b8b25e9b894ab229929f16019d7a88 = L.polyline(
#                 [[39.16426, -118.05048], [39.15125838285906, -118.04083958697115], [39.15125838285906, -118.06012041302884], [39.16426, -118.05048]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_b9943d0b560c6139a299459255e8066c);
#
#
#             poly_line_c2b8b25e9b894ab229929f16019d7a88.bindTooltip(
#                 `&lt;div&gt;
#                      First Line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var layer_control_d9cbad813cd654c9d70d3ca2e275c830 = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_1e15fb65db94a44c16c840a788a16de6,
#                 },
#                 overlays :  {
#                     &quot;Vehicle 1&quot; : feature_group_b9943d0b560c6139a299459255e8066c,
#                 },
#             };
#             L.control.layers(
#                 layer_control_d9cbad813cd654c9d70d3ca2e275c830.base_layers,
#                 layer_control_d9cbad813cd654c9d70d3ca2e275c830.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_bb16d9d6bba483f4340af8e34be20945);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Demo V1

# %%
def makeTriangle(StartLat, StartLong, TotalDist):
    SideDist = TotalDist/3
    origin = geopy.Point(StartLat, StartLong)
    Stop1 = geodesic(kilometers=SideDist).destination(origin, 150)
    Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
    Stop2 = geodesic(kilometers=SideDist).destination(origin, 210)
    Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
    coords_1=[[StartLat,StartLong],[Stop1Lat,Stop1Long],[Stop2Lat,Stop2Long],[StartLat,StartLong]]
    fig5=Figure(height=550,width=750)
    m5=folium.Map(location=[StartLat, StartLong],tiles='cartodbpositron',zoom_start=13)
    f1=folium.FeatureGroup("Vehicle 1")
    line_1=folium.vector_layers.PolyLine(coords_1,tooltip='Route',color='blue',weight=10).add_to(f1)
    folium.Marker(location=[StartLat,StartLong],icon=folium.Icon(color='red',icon='none')).add_to(m5)
    f1.add_to(m5)
    folium.LayerControl().add_to(m5)
    return m5

# %%
def makeSquare(StartLat, StartLong, TotalDist):
    SideDist = TotalDist/4
    origin = geopy.Point(StartLat, StartLong)
    Stop1 = geodesic(kilometers=SideDist).destination(origin, 90)
    Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
    Stop2 = geodesic(kilometers=SideDist).destination(Stop1, 180)
    Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
    Stop3 = geodesic(kilometers=SideDist).destination(origin, 180)
    Stop3Lat, Stop3Long = Stop3.latitude, Stop3.longitude
    coords_1=[[StartLat,StartLong],[Stop1Lat,Stop1Long],[Stop2Lat,Stop2Long],[Stop3Lat,Stop3Long],[StartLat,StartLong]]
    fig5=Figure(height=550,width=750)
    m5=folium.Map(location=[StartLat, StartLong],tiles='cartodbpositron',zoom_start=13)
    f1=folium.FeatureGroup("Vehicle 1")
    line_1=folium.vector_layers.PolyLine(coords_1,tooltip='Route',color='blue',weight=10).add_to(f1)
    folium.Marker(location=[StartLat,StartLong],icon=folium.Icon(color='red',icon='none')).add_to(m5)
    f1.add_to(m5)
    folium.LayerControl().add_to(m5)
    return m5

# %%
def makeStar(StartLat, StartLong, TotalDist):
    SideDist = TotalDist/5
    origin = geopy.Point(StartLat, StartLong)
    Stop1 = geodesic(kilometers=SideDist).destination(origin, 162)
    Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
    Stop2 = geodesic(kilometers=SideDist).destination(Stop1, 306)
    Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
    Stop3 = geodesic(kilometers=SideDist).destination(Stop2, 90)
    Stop3Lat, Stop3Long = Stop3.latitude, Stop3.longitude
    Stop4 = geodesic(kilometers=SideDist).destination(Stop3, 234)
    Stop4Lat, Stop4Long = Stop4.latitude, Stop4.longitude
    coords_1=[[StartLat,StartLong],[Stop1Lat,Stop1Long],[Stop2Lat,Stop2Long],[Stop3Lat,Stop3Long],[Stop4Lat,Stop4Long],[StartLat,StartLong]]
    fig5=Figure(height=550,width=750)
    m5=folium.Map(location=[StartLat, StartLong],tiles='cartodbpositron',zoom_start=14)
    f1=folium.FeatureGroup("Vehicle 1")
    line_1=folium.vector_layers.PolyLine(coords_1,tooltip='Route',color='blue',weight=10).add_to(f1)
    folium.Marker(location=[StartLat,StartLong],icon=folium.Icon(color='red',icon='none')).add_to(m5)
    f1.add_to(m5)
    folium.LayerControl().add_to(m5)
    return m5

# %%
result = 0
#StartLat = input("What is your Starting Latitude: ")
#StartLong = input("What is your Starting Longitude: ")
#StartLat = float(StartLat)
#StartLong = float(StartLong)
StartLoc = input("What is your Starting Location: ")
locator = Nominatim(user_agent = "myapp")
location = locator.geocode(StartLoc)
StartLat = location.latitude
StartLong = location.longitude
print('Location: ' + str(StartLat) + ', ' + str(StartLong))
TotalDist = input("How many miles do you want to run: ")
TotalDist = float(TotalDist)
TotalDist = TotalDist * 1.60934
# converts miles to km
Shape = input("What shape do you want to make: ")
if Shape.lower() == 'triangle':
    result = makeTriangle(StartLat, StartLong, TotalDist)
elif Shape.lower() == 'star':
    result = makeStar(StartLat, StartLong, TotalDist)
else:
    result = makeSquare(StartLat, StartLong, TotalDist)
result
# Out:
# What is your Starting Location: Pasadena City Hall
# Location: 34.14767185, -118.14386912573926
# How many miles do you want to run: 5
# What shape do you want to make: Star
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c80188a7fd2d9ffbd6951df4132d1ab0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c80188a7fd2d9ffbd6951df4132d1ab0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c80188a7fd2d9ffbd6951df4132d1ab0 = L.map(
#                 &quot;map_c80188a7fd2d9ffbd6951df4132d1ab0&quot;,
#                 {
#                     center: [34.14767185, -118.14386912573926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9e03bc21f6f251c6c6caa9f3e0ffb0c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c80188a7fd2d9ffbd6951df4132d1ab0);
#
#
#             var marker_545aa7068a6944dfd7afda35a41cef10 = L.marker(
#                 [34.14767185, -118.14386912573926],
#                 {}
#             ).addTo(map_c80188a7fd2d9ffbd6951df4132d1ab0);
#
#
#             var icon_2300db840d3720e11b687b03f09f2b0e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_545aa7068a6944dfd7afda35a41cef10.setIcon(icon_2300db840d3720e11b687b03f09f2b0e);
#
#
#             var feature_group_6b534b7dc779e600ae9f1810bda002c7 = L.featureGroup(
#                 {}
#             ).addTo(map_c80188a7fd2d9ffbd6951df4132d1ab0);
#
#
#             var poly_line_de9d52da47a20a9a6df4978bdb4ae7d5 = L.polyline(
#                 [[34.14767185, -118.14386912573926], [34.13387345130276, -118.13847758701309], [34.142400449757254, -118.15259423661048], [34.14239920982633, -118.13514509825497], [34.133870588536844, -118.14926032953818], [34.14767185, -118.14386912573926]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_6b534b7dc779e600ae9f1810bda002c7);
#
#
#             poly_line_de9d52da47a20a9a6df4978bdb4ae7d5.bindTooltip(
#                 `&lt;div&gt;
#                      Route
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var layer_control_b298f3062678eaf696e8a92ae5c12d3f = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_a9e03bc21f6f251c6c6caa9f3e0ffb0c,
#                 },
#                 overlays :  {
#                     &quot;Vehicle 1&quot; : feature_group_6b534b7dc779e600ae9f1810bda002c7,
#                 },
#             };
#             L.control.layers(
#                 layer_control_b298f3062678eaf696e8a92ae5c12d3f.base_layers,
#                 layer_control_b298f3062678eaf696e8a92ae5c12d3f.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c80188a7fd2d9ffbd6951df4132d1ab0);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## OSMnx Experiments

# %%
ox.config(log_console=True, use_cache=False)

# %%
StartLoc = input("What is your Address: ")
TotalDist = input("How many miles do you want to go: ")
TotalDist = float(TotalDist)
TotalDist = TotalDist * 1.60934
locator = Nominatim(user_agent = "myapp")
location = locator.geocode(StartLoc)
StartLat = location.latitude
StartLong = location.longitude
SideDist = TotalDist/5
origin = geopy.Point(StartLat, StartLong)
Stop1 = geodesic(kilometers=SideDist).destination(origin, 162)
Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
Stop2 = geodesic(kilometers=SideDist).destination(Stop1, 306)
Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
Stop3 = geodesic(kilometers=SideDist).destination(Stop2, 90)
Stop3Lat, Stop3Long = Stop3.latitude, Stop3.longitude
Stop4 = geodesic(kilometers=SideDist).destination(Stop3, 234)
Stop4Lat, Stop4Long = Stop4.latitude, Stop4.longitude
coords_1=[[StartLat,StartLong],[Stop1Lat,Stop1Long],[Stop2Lat,Stop2Long],[Stop3Lat,Stop3Long],[Stop4Lat,Stop4Long],[StartLat,StartLong]]
fig5=Figure(height=550,width=750)
m5=folium.Map(location=[StartLat, StartLong],tiles='cartodbpositron',zoom_start=14)
f1=folium.FeatureGroup("Vehicle 1")
line_1=folium.vector_layers.PolyLine(coords_1,tooltip='Route',color='blue',weight=10).add_to(f1)
folium.Marker(location=[StartLat,StartLong],icon=folium.Icon(color='red',icon='none')).add_to(m5)
f1.add_to(m5)
folium.LayerControl().add_to(m5)
m5
# Out:
# What is your Address: Pasadena City Hall
# How many miles do you want to go: 5
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6b6ba1189556d80a21e273868ae0ae0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6b6ba1189556d80a21e273868ae0ae0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e6b6ba1189556d80a21e273868ae0ae0 = L.map(
#                 &quot;map_e6b6ba1189556d80a21e273868ae0ae0&quot;,
#                 {
#                     center: [34.14767185, -118.14386912573926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9188ae602a84a4d93a0895adde446186 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e6b6ba1189556d80a21e273868ae0ae0);
#
#
#             var marker_544f49fb050cfcf4788dc186087b341c = L.marker(
#                 [34.14767185, -118.14386912573926],
#                 {}
#             ).addTo(map_e6b6ba1189556d80a21e273868ae0ae0);
#
#
#             var icon_8cf8a222971c8f2a5d35dc23df5853ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_544f49fb050cfcf4788dc186087b341c.setIcon(icon_8cf8a222971c8f2a5d35dc23df5853ec);
#
#
#             var feature_group_f95d445ad9adc3bd21a4ee78eda7f7f6 = L.featureGroup(
#                 {}
#             ).addTo(map_e6b6ba1189556d80a21e273868ae0ae0);
#
#
#             var poly_line_694d5bd9b5cc2824398f87d7823f577c = L.polyline(
#                 [[34.14767185, -118.14386912573926], [34.13387345130276, -118.13847758701309], [34.142400449757254, -118.15259423661048], [34.14239920982633, -118.13514509825497], [34.133870588536844, -118.14926032953818], [34.14767185, -118.14386912573926]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(feature_group_f95d445ad9adc3bd21a4ee78eda7f7f6);
#
#
#             poly_line_694d5bd9b5cc2824398f87d7823f577c.bindTooltip(
#                 `&lt;div&gt;
#                      Route
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var layer_control_8d40d8315333f2b734d50ef3604dcee4 = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_9188ae602a84a4d93a0895adde446186,
#                 },
#                 overlays :  {
#                     &quot;Vehicle 1&quot; : feature_group_f95d445ad9adc3bd21a4ee78eda7f7f6,
#                 },
#             };
#             L.control.layers(
#                 layer_control_8d40d8315333f2b734d50ef3604dcee4.base_layers,
#                 layer_control_8d40d8315333f2b734d50ef3604dcee4.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_e6b6ba1189556d80a21e273868ae0ae0);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
start_latlng = (StartLat, StartLong)
mode = 'walk'
optimizer = 'length'
graph = ox.graph_from_point(start_latlng, network_type = mode)
# change graph_from_point to have radius related to total distance eventually
start_node = ox.distance.nearest_nodes(graph, StartLong, StartLat)
stop1_node = ox.distance.nearest_nodes(graph, Stop1Long, Stop1Lat)
stop2_node = ox.distance.nearest_nodes(graph, Stop2Long, Stop2Lat)
stop3_node = ox.distance.nearest_nodes(graph, Stop3Long, Stop3Lat)
stop4_node = ox.distance.nearest_nodes(graph, Stop4Long, Stop4Lat)
route1 = ox.distance.shortest_path(graph, start_node, stop1_node, weight=optimizer, cpus=None)
route2 = ox.distance.shortest_path(graph, stop1_node, stop2_node, weight=optimizer, cpus=None)
route3 = ox.distance.shortest_path(graph, stop2_node, stop3_node, weight=optimizer, cpus=None)
route4 = ox.distance.shortest_path(graph, stop3_node, stop4_node, weight=optimizer, cpus=None)
route5 = ox.distance.shortest_path(graph, stop4_node, start_node, weight=optimizer, cpus=None)
final_route = route1 + route2[1:] + route3[1:] + route4[1:] + route5[1:]

# %%
final_route_map = ox.plot_route_folium(graph, final_route)
final_route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d84ff1895df2a8de0dbedbd18ac6a82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d84ff1895df2a8de0dbedbd18ac6a82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0d84ff1895df2a8de0dbedbd18ac6a82 = L.map(
#                 &quot;map_0d84ff1895df2a8de0dbedbd18ac6a82&quot;,
#                 {
#                     center: [34.1422566878251, -118.14310638225285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35c7f251a89ffc6b0de46611ba1bfddd = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d84ff1895df2a8de0dbedbd18ac6a82);
#
#
#             var poly_line_1e3c620dd8d03f81adc83f3b0a24e17e = L.polyline(
#                 [[34.147653, -118.1441067], [34.1475798, -118.1441029], [34.1475544, -118.1440984], [34.147517, -118.1440834], [34.1474498, -118.1440631], [34.1473567, -118.1440654]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d84ff1895df2a8de0dbedbd18ac6a82);
#
#
#             var poly_line_bf30332fdd71ec5b6fbe3199ebcd7a97 = L.polyline(
#                 [[34.1473567, -118.1440654], [34.1470303, -118.1440733]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d84ff1895df2a8de0dbedbd18ac6a82);
#
#
#             var poly_line_e6e12e762de0961f7d856e98d262935f = L.polyline(
#                 [[34.1470303, -118.1440733], [34.1468841, -118.1440769]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d84ff1895df2a8de0dbedbd18ac6a82);
#
#
#             var poly_line_7529d3bbced7a611a229642e137d55fb = L.polyline(
#                 [[34.1468841, -118.1440769], [34.1467988, -118.1440755]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d84ff1895df2a8de0dbedbd18ac6a82);
#
#
#             var poly_line_8c7fb34a5d94bec1b9a4e7ed83489d89 = L.polyline(
#                 [[34.1467988, -118.1440755], [34.1468053, -118.1438193], [34.1464013, -118.1438148]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d84ff1895df2a8de0dbedbd18ac6a82);
#
#
#             var poly_line_57ab908a6a1f363b13e7d84989d5ed5f = L.polyline(
#                 [[34.1464013, -118.1438148], [34.1458363, -118.1438085]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: n

# %% [markdown]
# ## Final Demo

# %%
def createTriangle(StartLat, StartLong, TotalDist):
    SideDist = TotalDist/3
    origin = geopy.Point(StartLat, StartLong)
    Stop1 = geodesic(kilometers=SideDist).destination(origin, 150)
    Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
    Stop2 = geodesic(kilometers=SideDist).destination(origin, 210)
    Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
    start_latlng = (StartLat, StartLong)
    mode = 'walk'
    optimizer = 'length'
    graph = ox.graph_from_point(start_latlng, network_type = mode)
    start_node = ox.distance.nearest_nodes(graph, StartLong, StartLat)
    stop1_node = ox.distance.nearest_nodes(graph, Stop1Long, Stop1Lat)
    stop2_node = ox.distance.nearest_nodes(graph, Stop2Long, Stop2Lat)
    route1 = ox.distance.shortest_path(graph, start_node, stop1_node, weight=optimizer, cpus=None)
    route2 = ox.distance.shortest_path(graph, stop1_node, stop2_node, weight=optimizer, cpus=None)
    route3 = ox.distance.shortest_path(graph, stop2_node, start_node, weight=optimizer, cpus=None)
    final_route = route1 + route2[1:] + route3[1:]
    return [graph, final_route]

# %%
def createSquare(StartLat, StartLong, TotalDist):
    SideDist = TotalDist/4
    origin = geopy.Point(StartLat, StartLong)
    Stop1 = geodesic(kilometers=SideDist).destination(origin, 90)
    Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
    Stop2 = geodesic(kilometers=SideDist).destination(Stop1, 180)
    Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
    Stop3 = geodesic(kilometers=SideDist).destination(origin, 180)
    Stop3Lat, Stop3Long = Stop3.latitude, Stop3.longitude
    start_latlng = (StartLat, StartLong)
    mode = 'walk'
    optimizer = 'length'
    graph = ox.graph_from_point(start_latlng, network_type = mode)
    start_node = ox.distance.nearest_nodes(graph, StartLong, StartLat)
    stop1_node = ox.distance.nearest_nodes(graph, Stop1Long, Stop1Lat)
    stop2_node = ox.distance.nearest_nodes(graph, Stop2Long, Stop2Lat)
    stop3_node = ox.distance.nearest_nodes(graph, Stop3Long, Stop3Lat)
    route1 = ox.distance.shortest_path(graph, start_node, stop1_node, weight=optimizer, cpus=None)
    route2 = ox.distance.shortest_path(graph, stop1_node, stop2_node, weight=optimizer, cpus=None)
    route3 = ox.distance.shortest_path(graph, stop2_node, stop3_node, weight=optimizer, cpus=None)
    route4 = ox.distance.shortest_path(graph, stop3_node, start_node, weight=optimizer, cpus=None)
    final_route = route1 + route2[1:] + route3[1:] + route4[1:]
    return [graph, final_route]

# %%
def createStar(StartLat, StartLong, TotalDist):
    SideDist = TotalDist/5
    origin = geopy.Point(StartLat, StartLong)
    Stop1 = geodesic(kilometers=SideDist).destination(origin, 162)
    Stop1Lat, Stop1Long = Stop1.latitude, Stop1.longitude
    Stop2 = geodesic(kilometers=SideDist).destination(Stop1, 306)
    Stop2Lat, Stop2Long = Stop2.latitude, Stop2.longitude
    Stop3 = geodesic(kilometers=SideDist).destination(Stop2, 90)
    Stop3Lat, Stop3Long = Stop3.latitude, Stop3.longitude
    Stop4 = geodesic(kilometers=SideDist).destination(Stop3, 234)
    Stop4Lat, Stop4Long = Stop4.latitude, Stop4.longitude
    start_latlng = (StartLat, StartLong)
    mode = 'walk'
    optimizer = 'length'
    graph = ox.graph_from_point(start_latlng, network_type = mode)
    start_node = ox.distance.nearest_nodes(graph, StartLong, StartLat)
    stop1_node = ox.distance.nearest_nodes(graph, Stop1Long, Stop1Lat)
    stop2_node = ox.distance.nearest_nodes(graph, Stop2Long, Stop2Lat)
    stop3_node = ox.distance.nearest_nodes(graph, Stop3Long, Stop3Lat)
    stop4_node = ox.distance.nearest_nodes(graph, Stop4Long, Stop4Lat)
    route1 = ox.distance.shortest_path(graph, start_node, stop1_node, weight=optimizer, cpus=None)
    route2 = ox.distance.shortest_path(graph, stop1_node, stop2_node, weight=optimizer, cpus=None)
    route3 = ox.distance.shortest_path(graph, stop2_node, stop3_node, weight=optimizer, cpus=None)
    route4 = ox.distance.shortest_path(graph, stop3_node, stop4_node, weight=optimizer, cpus=None)
    route5 = ox.distance.shortest_path(graph, stop4_node, start_node, weight=optimizer, cpus=None)
    final_route = route1 + route2[1:] + route3[1:] + route4[1:] + route5[1:]
    return [graph, final_route]

# %%
graph = 0
final_route = 0
StartLoc = input("What is your Starting Location: ")
locator = Nominatim(user_agent = "myapp")
location = locator.geocode(StartLoc)
StartLat = location.latitude
StartLong = location.longitude
print('Location: ' + str(StartLat) + ', ' + str(StartLong))
TotalDist = input("How many miles do you want to run: ")
TotalDist = float(TotalDist)
TotalDist = TotalDist * 1.60934
Shape = input("What shape do you want to make: ")
if Shape.lower() == 'triangle':
    result = createTriangle(StartLat, StartLong, TotalDist)
    graph = result[0]
    final_route = result[1]
elif Shape.lower() == 'star':
    result = createStar(StartLat, StartLong, TotalDist)
    graph = result[0]
    final_route = result[1]
else:
    result = createSquare(StartLat, StartLong, TotalDist)
    graph = result[0]
    final_route = result[1]
final_route_map = ox.plot_route_folium(graph, final_route)
final_route_map
# Out:
# What is your Starting Location: taipei
# Location: 25.0375198, 121.5636796
# How many miles do you want to run: 5
# What shape do you want to make: star
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0eee3d5a89897a872b730d56409c09fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0eee3d5a89897a872b730d56409c09fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0eee3d5a89897a872b730d56409c09fc = L.map(
#                 &quot;map_0eee3d5a89897a872b730d56409c09fc&quot;,
#                 {
#                     center: [25.032479446729337, 121.56397691943185],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6d8db2f25eb864bc5f859b4d0800e8d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0eee3d5a89897a872b730d56409c09fc);
#
#
#             var poly_line_f04261454eb557eb6c4c5f4f6d82cb0d = L.polyline(
#                 [[25.0375223, 121.5636109], [25.0373254, 121.5636066]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0eee3d5a89897a872b730d56409c09fc);
#
#
#             var poly_line_bf260f9b6740a8ba615c84221d116c40 = L.polyline(
#                 [[25.0373254, 121.5636066], [25.03732, 121.5637092]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0eee3d5a89897a872b730d56409c09fc);
#
#
#             var poly_line_b0ebcee802782e0f168a99632cddc712 = L.polyline(
#                 [[25.03732, 121.5637092], [25.0360588, 121.5637024]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0eee3d5a89897a872b730d56409c09fc);
#
#
#             var poly_line_6a3e02d777c1c20aa94a1465c4679cdd = L.polyline(
#                 [[25.0360588, 121.5637024], [25.0360542, 121.5639963]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0eee3d5a89897a872b730d56409c09fc);
#
#
#             var poly_line_79eaa163ee3d9816df680631ea641d01 = L.polyline(
#                 [[25.0360542, 121.5639963], [25.0360503, 121.5643175]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0eee3d5a89897a872b730d56409c09fc);
#
#
#             var poly_line_ae5401314e7d2d91c809bb2a7c129619 = L.polyline(
#                 [[25.0360503, 121.5643175], [25.0360213, 121.5649965]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot
